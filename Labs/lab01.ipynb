# %% [markdown]
# # Project 1 : Exploratory Data Analysis - Gapminder dataset
#
# The Gapminder dataset provides population data from 1952 to 2007 (at 5 year intervals) for several countries around the world . Compare the populations of European countries France ,United KIngdom , Italy , Germany and Spain over this period using a line chart . Make appropiate modifications to the line chart title , axis title , legend , figure size , font size , colors ,etc. to make the chart readable and visually appealing - #Line Chart

# %%
import pandas as pd
import matplotlib.pyplot as plt
population_df = pd.read_csv("S:\Sem -2\ML2026_Atul\datasets\gapminderDataFiveYear.csv")

countries = ['France', 'United Kingdom', 'Italy', 'Germany', 'Spain']
filtered_df = population_df[population_df['country'].isin(countries)]

pivot_df = filtered_df.pivot(index='year', columns='country', values='pop')

plt.figure(figsize=(14, 10))
colors = ['red', 'blue', 'black', 'pink', 'purple']
for i, country in enumerate(countries):
    plt.plot(pivot_df.index, pivot_df[country], label=country, color=colors[i], marker='o', linewidth=2)

plt.title('Population Growth of European Countries (1952-2007)', fontsize=16, fontweight='bold')
plt.xlabel('Year', fontsize=14)
plt.ylabel('Population (in millions)', fontsize=14)
plt.legend(title='Country', fontsize=12)
plt.grid(True, alpha=0.3)
plt.xticks(pivot_df.index, rotation=45)
plt.tight_layout()

plt.show()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\S'
# <>:3: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\imatu\AppData\Local\Temp\ipykernel_6096\94767203.py:3: SyntaxWarning: invalid escape sequence '\S'
#   population_df = pd.read_csv("S:\Sem -2\ML2026_Atul\datasets\gapminderDataFiveYear.csv")

# %% [markdown]
# # Project 2 : Exploratory Data Analysis - Diamonds dataset
# Diamonds_url points to a CSV file containing varnous attrbutes like carat, cut, color, clarly, prlce etc, for over 53, 000 dlamonds, Visualize the relationship between, the carat (size of diamond)and price using a scatter plot Instead of using the entire dataset for this visualizatlon, just pick the diamonds with a clarily "SI2" and color "E", Use the values of the "'cut' column to color the dots in the scatter plot Make appropriate modifications to the chart title, axis, legend, figure size, font size, colors ete, to make the chart readable and visually appealing # Scatterplot

# %%
import pandas as pd

diamond_df = pd.read_csv("S:\Sem -2\ML2026_Atul\datasets\diamonds.csv")


import matplotlib.pyplot as plt

filtered_diamonds = diamond_df[(diamond_df['clarity'] == 'SI2') & (diamond_df['color'] == 'E')]


cut_colors = {'Fair': 'red', 'Good': 'orange', 'Very Good': 'yellow', 'Premium': 'black', 'Ideal': 'blue'}
colors = filtered_diamonds['cut'].map(cut_colors)


plt.figure(figsize=(12, 8))
scatter = plt.scatter(filtered_diamonds['carat'], filtered_diamonds['price'], c=colors, alpha=0.7, edgecolors='w', s=50)


handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10, alpha=0.7) for color in cut_colors.values()]
plt.legend(handles, cut_colors.keys(), title='Cut Quality', fontsize=12, title_fontsize=14)


plt.title('Scatter Plot: Carat vs Price for Diamonds (Clarity: SI2, Color: E)', fontsize=16, fontweight='bold')
plt.xlabel('Carat (Weight)', fontsize=14)
plt.ylabel('Price (USD)', fontsize=14)
plt.grid(True, alpha=0.3)
plt.tight_layout()


plt.show()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\S'
# <>:3: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\imatu\AppData\Local\Temp\ipykernel_23172\4124312612.py:3: SyntaxWarning: invalid escape sequence '\S'
#   diamond_df = pd.read_csv("S:\Sem -2\ML2026_Atul\datasets\diamonds.csv")
